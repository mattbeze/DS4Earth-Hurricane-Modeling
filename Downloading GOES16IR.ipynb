# %%
import wget
import datetime
from urllib.error import HTTPError

# %%
baseURL = "https://www.ncdc.noaa.gov/gibbs/image/GOE-16/IR/"
delta = datetime.timedelta(hours = 3)
last = datetime.datetime(2020, 1, 1, 0)
frame = datetime.datetime(2018, 1, 1, 0)

while frame < last:
    filename = frame.strftime("%Y-%m-%d-%H")
    try:
        wget.download(baseURL + filename, "pics/%s.jpg" % filename)
    except HTTPError:
        print(filename + " missing")
    frame += delta
# Out:
# 2018-01-06-21 missing
# 2018-01-07-00 missing
# 2018-01-28-21 missing
# 2018-01-29-00 missing
# 2018-04-20-06 missing
# 2018-07-27-00 missing
# 2018-07-31-15 missing
# 2018-08-01-00 missing
# 2018-10-03-09 missing
# 2018-10-19-21 missing
# 2018-10-20-12 missing
# 2018-10-23-12 missing
# 2018-11-08-09 missing
# 2018-12-26-18 missing
# 2018-12-31-00 missing
# 2018-12-31-03 missing
# 2018-12-31-06 missing
# 2018-12-31-09 missing
# 2018-12-31-12 missing
# 2018-12-31-15 missing
# 2018-12-31-18 missing
# 2018-12-31-21 missing
# 2019-01-04-00 missing
# 2019-02-21-21 missing
# 2019-02-25-18 missing
# 2019-02-25-21 missing
# 2019-03-02-09 missing
# 2019-03-06-09 missing
# 2019-03-12-18 missing
# 2019-03-29-09 missing
# 2019-03-31-09 missing
# 2019-03-31-21 missing
# 2019-06-27-15 missing
# 2019-06-28-18 missing
# 2019-07-10-15 missing
# 2019-07-26-15 missing
# 2019-07-26-18 missing
# 2019-07-26-21 missing
# 2019-09-30-15 missing
# 2019-10-01-12 missing
# 2019-10-30-00 missing
# 2019-10-30-03 missing
# 2019-10-30-06 missing
# 2019-10-30-09 missing
# 2019-10-30-12 missing
# 2019-10-30-15 missing
# 2019-10-30-18 missing
# 2019-10-30-21 missing
# 2019-10-31-00 missing
# 2019-10-31-03 missing
# 2019-10-31-06 missing
# 2019-10-31-09 missing
# 2019-10-31-12 missing
# 2019-10-31-15 missing
# 2019-10-31-18 missing
# 2019-10-31-21 missing
# 2019-11-01-00 missing
# 2019-11-01-03 missing
# 2019-11-01-06 missing
# 2019-11-01-09 missing
# 2019-11-01-12 missing
# 2019-11-01-15 missing
# 2019-11-01-18 missing
# 2019-11-01-21 missing
# 2019-11-02-00 missing
# 2019-11-02-03 missing
# 2019-11-02-06 missing
# 2019-11-02-09 missing
# 2019-11-02-12 missing
# 2019-11-02-15 missing
# 2019-11-02-18 missing
# 2019-11-02-21 missing
# 2019-11-03-00 missing
# 2019-11-03-03 missing
# 2019-11-03-06 missing
# 2019-11-03-09 missing
# 2019-11-03-12 missing
# 2019-11-03-15 missing
# 2019-11-03-18 missing
# 2019-11-03-21 missing
# 2019-11-04-00 missing
# 2019-11-04-03 missing
# 2019-11-04-06 missing
# 2019-11-04-09 missing
# 2019-11-04-12 missing
# 2019-11-04-15 missing
# 2019-11-04-18 missing
# 2019-11-04-21 missing
# 2019-11-05-00 missing
# 2019-11-05-03 missing
# 2019-11-05-06 missing
# 2019-11-05-09 missing
# 2019-11-05-12 missing
# 2019-11-05-15 missing
# 2019-11-05-18 missing
# 2019-11-05-21 missing
# 2019-11-06-00 missing
# 2019-11-06-03 missing
# 2019-11-06-06 missing
# 2019-11-06-09 missing
# 2019-11-06-12 missing
# 2019-11-06-15 missing
# 2019-11-06-18 missing
# 2019-11-06-21 missing
# 2019-11-07-00 missing
# 2019-11-07-03 missing
# 2019-11-07-06 missing
# 2019-11-07-09 missing
# 2019-11-07-12 missing
# 2019-11-07-15 missing
# 2019-11-07-18 missing
# 2019-11-07-21 missing
# 2019-11-08-00 missing
# 2019-11-08-03 missing
# 2019-11-08-06 missing
# 2019-11-08-09 missing
# 2019-11-08-12 missing
# 2019-11-08-15 missing
# 2019-11-08-18 missing
# 2019-11-08-21 missing
# 2019-11-09-00 missing
# 2019-11-09-03 missing
# 2019-11-09-06 missing
# 2019-11-09-09 missing
# 2019-11-09-12 missing
# 2019-11-09-15 missing
# 2019-11-09-18 missing
# 2019-11-09-21 missing
# 2019-11-12-21 missing
# 2019-12-02-00 missing
